# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasjustel30/BancoDeDados.py/blob/main/Filtros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import random

# %%
lib = {
    'times' : ['Ipiranga' , 'Bandeirantes' ,  'Brooklin'],
    'nacionais' : [12,7,9],
    'continentais' : [2,4,3]
}

df = pd.DataFrame(lib)

print(df)
# Out:
#           times  nacionais  continentais
# 0      Ipiranga         12             2
# 1  Bandeirantes          7             4
# 2      Brooklin          9             3

# %%
lib = {
    'times' : ['Ipiranga' , 'Bandeirantes' ,  'Brooklin' , 'America'],
    'nacionais' : [12,7,9,8],
    'continentais' : [2,4,3,5],
    'mundiais' : [2,3,0,2]
}

df = pd.DataFrame(lib)

df.sort_values(by= ['mundiais'] ,inplace=True)

df.iloc[1:2]
# Out:
#       times  nacionais  continentais  mundiais
# 0  Ipiranga         12             2         2

# %%
lib = {
    'times' : ['Ipiranga' , 'Bandeirantes' ,  'Brooklin','America'],
    'nacionais' : [12,7,9,8],
    'continentais' : [2,4,3,5],
    'mundiais' : [2,3,0,2],
}

df = pd.DataFrame(lib)

df.loc[1:2]
# Out:
#           times  nacionais  continentais  mundiais
# 1  Bandeirantes          7             4         3
# 2      Brooklin          9             3         0

# %%
lib = {
    'times' : ['Ipiranga' , 'Bandeirantes' ,  'Brooklin','America'],
    'nacionais' : [12,7,9,8],
    'continentais' : [2,4,3,5],
    'mundiais' : [2,3,0,2],
}

df = pd.DataFrame(lib)

df.iloc[1:3]
# Out:
#           times  nacionais  continentais  mundiais
# 1  Bandeirantes          7             4         3
# 2      Brooklin          9             3         0

# %%
df = pd.read_csv('data.txt')

df.loc[0:2 , ['acao','setor']]
# Out:
#     acao       setor
# 0  PETR4   commodity
# 1  BBAS3       banco
# 2  BBSE3  seguradora

# %%
df.iloc[0:3,0:3]
# Out:
#     acao  posicao       setor
# 0  PETR4    12.90   commodity
# 1  BBAS3    11.84       banco
# 2  BBSE3    10.23  seguradora

# %%
df[df['posicao']>10.0]
# Out:
#     acao  posicao       setor
# 0  PETR4    12.90   commodity
# 1  BBAS3    11.84       banco
# 2  BBSE3    10.23  seguradora

# %%
df.query('posicao < 8')
# Out:
#     acao  posicao    setor
# 6  ITUB4     7.36    banco
# 7  CPLE6     6.36  energia

# %%
df.query('setor == "commodity" ')
# Out:
#     acao  posicao      setor
# 0  PETR4    12.90  commodity
# 3  VALE3     9.44  commodity

# %%
df.query('setor != "commodity" ')
# Out:
#      acao  posicao       setor
# 1   BBAS3    11.84       banco
# 2   BBSE3    10.23  seguradora
# 4   ENBR3     9.34     energia
# 5  SANB11     8.76       banco
# 6   ITUB4     7.36       banco
# 7   CPLE6     6.36     energia

# %%
df.query('setor !=  "banco"  & posicao > 10')
# Out:
#     acao  posicao       setor
# 0  PETR4    12.90   commodity
# 2  BBSE3    10.23  seguradora

# %%
df['setor'].value_counts()
# Out:
# banco         3
# commodity     2
# energia       2
# seguradora    1
# Name: setor, dtype: int64
